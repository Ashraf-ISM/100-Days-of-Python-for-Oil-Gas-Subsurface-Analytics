# %% [markdown]
# A tadpole plot summarizes two important things:
#
# Dip angle → how steep the plane is dipping
# Dip direction / azimuth → which direction it dips toward
#
# These features are picked from sinusoidal traces on image logs.
